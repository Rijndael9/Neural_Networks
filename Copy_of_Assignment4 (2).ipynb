# %% [markdown]
# # Starter code: network for Irises in Pytorch
#
#
# In the following cells a feedforward neural network has been implemented with the aid of PyTorch and its autograd mechanism. Please study the code - many network implementations follow a similar pattern.
#
# The provided network trains to nearly 100% accuracy on Iris using Batch Gradient Descent.

# %% [markdown]
# # Assignment 4
#
# **Submission deadline:**
#
# **problems 1-2 last lab session before or on Wednesday, 30.11.18**
#
# **problems 3-8 last lab session before or on Wednesday, 7.12.18**
#
#
# **Points: 11 + 5 bonus points**
#
#
# ## Downloading this notebook
#
# This assignment is an Colab/Jupyter notebook. Download it by cloning https://github.com/janchorowski/nn_assignments. Follow the instructions in its README for instructions.
#
# Please do not hesitate to use GitHub’s pull requests to send us corrections!
#
# If you use Colab please make sure to have a GPU runtime (```Runtime -> Change runtime type -> Hardware Accelarater = GPU```)

# %%
# Please note that this code needs only to be run in a fresh runtime.
# However, it can be rerun afterwards too.
# !pip install -q gdown httpimport
![ -e cifar.npz ] || gdown 'https://drive.google.com/uc?id=1oBzZdtg2zNTPGhbRy6DQ_wrf5L5OAhNR' -O cifar.npz
![ -e mnist.npz ] || gdown 'https://drive.google.com/uc?id=1QPaC3IKB_5tX6yIZgRgkpcqFrfVqPTXU' -O mnist.npz

# http://pytorch.org/
from os.path import exists
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision
import torch
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1oBzZdtg2zNTPGhbRy6DQ_wrf5L5OAhNR
# To: /content/cifar.npz
# 185MB [00:01, 153MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1QPaC3IKB_5tX6yIZgRgkpcqFrfVqPTXU
# To: /content/mnist.npz
# 55.4MB [00:00, 152MB/s]
# tcmalloc: large alloc 1073750016 bytes == 0x55f9958b6000 @  0x7f357b0932a4 0x55f93cfc7f18 0x55f93d0bba85 0x55f93cfdb4ca 0x55f93cfe0232 0x55f93cfd8d0a 0x55f93cfe05fe 0x55f93cfd8d0a 0x55f93cfe05fe 0x55f93cfd8d0a 0x55f93cfe05fe 0x55f93cfd8d0a 0x55f93cfe0c38 0x55f93cfd8d0a 0x55f93cfe05fe 0x55f93cfd8d0a 0x55f93cfe05fe 0x55f93cfe0232 0x55f93cfe0232 0x55f93cfd8d0a 0x55f93cfe0c38 0x55f93cfe0232 0x55f93cfd8d0a 0x55f93cfe0c38 0x55f93cfd8d0a 0x55f93cfe0c38 0x55f93cfd8d0a 0x55f93cfe05fe 0x55f93cfd8d0a 0x55f93cfd8629 0x55f93d00961f

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Getting to know PyTorch
#
# From now on, we will use [pytorch](https://pytorch.org/) to implement neural networks.
#
# Good introductions are the [60-minute tutorial](https://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html) and [pytorch examples](https://pytorch.org/tutorials/beginner/pytorch_with_examples.html).
#
#
# Pytorch has a set of modules to build neural networks. However, for simplicity, this assignment will use a custom, simple neural network code.

# %%
import numpy as np
import time
import torch
import torch.nn.functional as F


class Layer(object):
    
    def train_mode(self):
        """Put layer into training mode.
        
        This is useful for e.g. Dropout.
        """
        pass
    
    def eval_mode(self):
        """Put layer into evalation mode.
        
        This is useful for e.g. Dropout.
        """
        pass
    
    def to_device(self, device):
        """Move this layer's parameters to thie given device (cpu/cuda).
        """
        
        pass
    
    @property
    def parameters(self):
        return []
    
    def __repr__(self):
        param_s = ', '.join(['%s%s' % (n, tuple(p.size())) 
                                 for (n,p) in self.parameters])
        if not param_s:
            return '  %s with no params' % (self.__class__.__name__)
        else:
            return '  %s with params: %s' % (self.__class__.__name__, param_s)
    

class AffineLayer(Layer):
    def __init__(self, num_in, num_out):
        self.W = torch.empty(num_in, num_out, dtype=torch.float32, requires_grad=True)
        self.b = torch.empty(1, num_out, dtype=torch.float32, requires_grad=True)
    
    @property
    def parameters(self):
        return [('W', self.W), ('b', self.b)]
    
    def forward(self, x):
        return x.mm(self.W) + self.b
    
    def to_device(self, device):
        with torch.no_grad():
            self.W = self.W.to(device).requires_grad_()
            self.b = self.b.to(device).requires_grad_()

    
class TanhLayer(Layer):
    def forward(self, x):
        return F.tanh(x)

    
class  ReLULayer(Layer):
    def forward(self, x):
        return F.relu(x)


class SoftMaxLayer(Layer):
    def forward(self, x):
        return F.softmax(x, dim=-1)

class CrossEntropyLoss:
    def forward(self, probs, targets):
        return torch.mean(-torch.log(torch.gather(
            probs, 1, targets.unsqueeze(1))))

# %%
class FeedforwardNet(object):
    def __init__(self, layers):
        self.layers = layers
        self.loss_fn = CrossEntropyLoss()

    @property
    def parameters(self):
        params = []
        for layer in self.layers:
            params += layer.parameters
        return params

    @parameters.setter
    def parameters(self, values):
        for (_, ownP), newP in zip(self.parameters, values):
            ownP.data = newP.data
    
    def to_device(self, device):
        for layer in self.layers:
            layer.to_device(device)
    
    def train_mode(self):
        for layer in self.layers:
            layer.train_mode()
    
    def eval_mode(self):
        for layer in self.layers:
            layer.eval_mode()    
    
    def forward(self, x):
        for layer in self.layers:
            x = layer.forward(x)
        return x
    
    def loss(self, outputs, targets):
        return self.loss_fn.forward(outputs, targets)
    
    def __repr__(self):
        strs = ["Feedorward network with %d layers:" % (len(self.layers),)]
        for layer in self.layers:
            strs.append(repr(layer))
        return '\n'.join(strs)

# %%
from sklearn import datasets

iris = datasets.load_iris()
IrisX = iris.data.astype(np.float32)
IrisX = (IrisX - IrisX.mean(axis=0, keepdims=True)) / IrisX.std(axis=0, keepdims=True)
IrisY = iris.target

IrisX = torch.from_numpy(IrisX)
IrisY = torch.from_numpy(IrisY)

# %%
def GD(model, x, y, alpha=1e-4, max_iters=1000000, tolerance=1e-6, device='cpu'):
    """Simple batch gradient descent"""
    x = x.to(device)
    y = y.to(device)
    model.to_device(device)
    try:
        old_loss = np.inf
        model.train_mode()
        tstart = time.time()
        for i in xrange(max_iters):
            outputs = model.forward(x)
            loss = model.loss(outputs, y)

            loss.backward()
            
            # this disables autograd mechanism and allows us to 
            with torch.torch.no_grad():
                for _, p in model.parameters:
                    p -= p.grad * alpha
                    # Zero gradients for the next iteration
                    p.grad.zero_()

            loss = loss.item()
            if old_loss < loss:
                print "Iter: %d, loss increased!" % (i,)
            if (old_loss - loss) < tolerance:
                print "Tolerance level reached. Exiting."
                break
            if i % 1000 == 0:
                _, predictions = outputs.data.max(dim=1)
                err_rate = 100.0 * (predictions != y.data).sum() / outputs.size(0)
                print "Iteration {0: >6} | loss {1: >5.2f} | err rate  {2: >5.2f}% | steps/s {3: >5.2f}" \
                      .format(i, loss, err_rate, (1000 if i else 1) / (time.time() - tstart))
                tstart = time.time()
            old_loss = loss
    except KeyboardInterrupt:
        pass

# %%
model = FeedforwardNet(
    [AffineLayer(4, 10),
     TanhLayer(),
     AffineLayer(10, 3),
     SoftMaxLayer(),
    ])


# Initialize parameters
with torch.torch.no_grad():
    for n, p in model.parameters:
        if n == 'W':
            #p.data.normal_(0, 0.05)
            p.uniform_(-0.1, 0.1)
        elif n == 'b':
            p.zero_()
        else:
            raise ValueError('Unknown parameter name "%s"' % p.name)

# Train
# Iris is so small, that trainingon CPU is faster!
GD(model, IrisX, IrisY, alpha=1e-1, tolerance=1e-7, device='cpu')
# Out:
# /usr/local/lib/python2.7/dist-packages/torch/nn/functional.py:995: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Iteration      0 | loss  1.11 | err rate  88.00% | steps/s 15.48
# Iteration   1000 | loss  0.05 | err rate   2.00% | steps/s 1600.48
# Iteration   2000 | loss  0.04 | err rate   2.00% | steps/s 1613.76
# Iteration   3000 | loss  0.04 | err rate   1.00% | steps/s 1617.76
# Iteration   4000 | loss  0.04 | err rate   1.00% | steps/s 1609.11
# Iteration   5000 | loss  0.04 | err rate   1.00% | steps/s 1646.93
# Iteration   6000 | loss  0.04 | err rate   1.00% | steps/s 1663.24
# Iteration   7000 | loss  0.04 | err rate   1.00% | steps/s 1626.86
# Iteration   8000 | loss  0.04 | err rate   1.00% | steps/s 1665.47
# Iteration   9000 | loss  0.04 | err rate   1.00% | steps/s 1647.32
# Iteration  10000 | loss  0.04 | err rate   1.00% | steps/s 1618.32
# Iteration  11000 | loss  0.04 | err rate   1.00% | steps/s 1661.41
# Iteration  12000 | loss  0.04 | err rate   1.00% | steps/s 1641.52
# Iteration  13000 | loss  0.04 | err rate   1.00% | steps/s 1652.90
# Iteration  14000 | loss  0.04 | err rate   1.00% | steps/s 1661.79
# Iteration  15000 | loss  0.04 | err rate   1.00% | steps/s 1636.16
# Iteration  16000 | loss  0.04 | err rate   1.00% | steps/s 1672.56
# Iteration  17000 | loss  0.04 | err rate   1.00% | steps/s 1650.63
# Iteration  18000 | loss  0.04 | err rate   1.00% | steps/s 1665.68
# Iteration  19000 | loss  0.04 | err rate   1.00% | steps/s 1673.46
# Iteration  20000 | loss  0.04 | err rate   1.00% | steps/s 1678.62
# Iteration  21000 | loss  0.04 | err rate   1.00% | steps/s 1639.14
# Iteration  22000 | loss  0.03 | err rate   1.00% | steps/s 1663.97
# Iteration  23000 | loss  0.03 | err rate   1.00% | steps/s 1680.44
# Iteration  24000 | loss  0.03 | err rate   1.00% | steps/s 1651.72
# Iteration  25000 | loss  0.03 | err rate   1.00% | steps/s 1651.84
# Iteration  26000 | loss  0.03 | err rate   1.00% | steps/s 1658.02
# Iteration  27000 | loss  0.03 | err rate   1.00% | steps/s 1659.56
# Iteration  28000 | loss  0.03 | err rate   1.00% | steps/s 1673.76
# Iteration  29000 | loss  0.03 | err rate   1.00% | steps/s 1674.07
# Iteration  30000 | loss  0.03 | err rate   1.00% | steps/s 1674.80
# Iteration  31000 | loss  0.03 | err rate   1.00% | steps/s 1665.10
# Iteration  32000 | loss  0.03 | err rate   1.00% | steps/s 1655.18
# Iteration  33000 | loss  0.03 | err rate   1.00% | steps/s 1671.51
# Iteration  34000 | loss  0.03 | err rate   1.00% | steps/s 1647.98
# Iteration  35000 | loss  0.03 | err rate   1.00% | steps/s 1650.30
# Iteration  36000 | loss  0.02 | err rate   1.00% | steps/s 1626.16
# Iteration  37000 | loss  0.02 | err rate   1.00% | steps/s 1656.64
# Iteration  38000 | loss  0.02 | err rate   1.00% | steps/s 1649.42
# Iteration  39000 | loss  0.02 | err rate   1.00% | steps/s 1637.72
# Iteration  40000 | loss  0.02 | err rate   0.00% | steps/s 1655.84
# Iteration  41000 | loss  0.02 | err rate   0.00% | steps/s 1632.87
# Iteration  42000 | loss  0.02 | err rate   0.00% | steps/s 1655.54
# Iteration  43000 | loss  0.02 | err rate   0.00% | steps/s 1637.78
# Iteration  44000 | loss  0.01 | err rate   0.00% | steps/s 1647.81
# Iteration  45000 | loss  0.01 | err rate   0.00% | steps/s 1658.53
# Iteration  46000 | loss  0.01 | err rate   0.00% | steps/s 1629.02
# Iteration  47000 | loss  0.01 | err rate   0.00% | steps/s 1663.01
# Iteration  48000 | loss  0.01 | err rate   0.00% | steps/s 1647.20
# Iteration  49000 | loss  0.01 | err rate   0.00% | steps/s 1638.63
# Iteration  50000 | loss  0.01 | err rate   0.00% | steps/s 1666.82
# Iteration  51000 | loss  0.01 | err rate   0.00% | steps/s 1629.82
# Iteration  52000 | loss  0.01 | err rate   0.00% | steps/s 1670.75
# Iteration  53000 | loss  0.01 | err rate   0.00% | steps/s 1628.90
# Iteration  54000 | loss  0.01 | err rate   0.00% | steps/s 1648.94
# Iteration  55000 | loss  0.01 | err rate   0.00% | steps/s 1669.78
# Iteration  56000 | loss  0.01 | err rate   0.00% | steps/s 1641.75
# Iteration  57000 | loss  0.00 | err rate   0.00% | steps/s 1658.77
# Iteration  58000 | loss  0.00 | err rate   0.00% | steps/s 1647.49
# Iteration  59000 | loss  0.00 | err rate   0.00% | steps/s 1652.27
# Iteration  60000 | loss  0.00 | err rate   0.00% | steps/s 1635.52
# Iteration  61000 | loss  0.00 | err rate   0.00% | steps/s 1656.31
# Iteration  62000 | loss  0.00 | err rate   0.00% | steps/s 1678.48
# Iteration  63000 | loss  0.00 | err rate   0.00% | steps/s 1666.70
# Iteration  64000 | loss  0.00 | err rate   0.00% | steps/s 1639.38
# Iteration  65000 | loss  0.00 | err rate   0.00% | steps/s 1681.99
# Iteration  66000 | loss  0.00 | err rate   0.00% | steps/s 1659.22
# Iteration  67000 | loss  0.00 | err rate   0.00% | steps/s 1677.91
# Iteration  68000 | loss  0.00 | err rate   0.00% | steps/s 1663.11
# Iteration  69000 | loss  0.00 | err rate   0.00% | steps/s 1664.73
# Tolerance level reached. Exiting.

# %% [markdown]
# # Starter code for MNIST and SGD scaffolding

# %%
import os
import torch
import torchvision


batch_size = 128
data_path = './data'

transform = torchvision.transforms.Compose(
    [torchvision.transforms.ToTensor(),
     torchvision.transforms.Normalize((0.1307,), (0.3081,)),
    ])

_test = torchvision.datasets.MNIST(
    data_path, train=False, download=True, transform=transform)

# Load training data, split into train and valid sets
_train = torchvision.datasets.MNIST(
    data_path, train=True, download=True, transform=transform)
_train.train_data = _train.train_data[:50000]
_train.train_labels = _train.train_labels[:50000]

_valid = torchvision.datasets.MNIST(
    data_path, train=True, download=True, transform=transform)
_valid.train_data = _valid.train_data[50000:]
_valid.train_labels = _valid.train_labels[50000:]

mnist_loaders = {
    'train': torch.utils.data.DataLoader(
        _train, batch_size=batch_size, shuffle=True,
        pin_memory=True, num_workers=10),
    'valid': torch.utils.data.DataLoader(
        _valid, batch_size=batch_size, shuffle=False),
    'test': torch.utils.data.DataLoader(
        _test, batch_size=batch_size, shuffle=False)}
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Processing...
# Done!

# %% [markdown]
# # Problem 1: Stochastic Gradient Descent [3p]
# Implement the following additions to the SGD code provided above:
#   1. **[1p]** momentum
#   2. **[1p]** learning rate schedule
#   3. **[1p]** weight decay, in which we additionally minimize for each weight matrix (but typically not the bias) the sum of its elements squared. One way to implement it is to use function `model.parameters` and select all parameters whose names are "`W`" and not "`b`".

# %%
def compute_error_rate(model, data_loader, device='cpu'):
    model.eval_mode()
    num_errs = 0.0
    num_examples = 0
    # we don't need gradient during eval!
    with torch.no_grad():
        for x, y in data_loader:
            x = x.to(device).view(x.size(0), -1)
            y = y.to(device)
            outputs = model.forward(x)
            _, predictions = outputs.data.max(dim=1)
            num_errs += (predictions != y.data).sum().item()
            num_examples += x.size(0)
    return 100.0 * num_errs / num_examples

# %%
import numpy as np

def SGD(model, data_loaders, alpha=1e-4, num_epochs=1, patience_expansion=1.5,
        log_every=100, device='cpu'):
    model.to_device(device)
    #
    # TODO: Initialize momentum variables
    # Hint: You need one velocity matrix for each parameter
    velocities = [torch.zeros(l[1].shape[0], l[1].shape[1]) for l in model.parameters]  
    #
    iter_ = 0
    epoch = 0
    alpha0 = alpha
    iter_ = 0
    regularisation = 0.001
    best_params = None
    best_val_err = np.inf
    history = {'train_losses': [], 'train_errs': [], 'val_errs': []}
    print('Training the model!')
    print('Interrupt at any time to evaluate the best validation model so far.')
    try:
        tstart = time.time()
        siter = iter_
        while epoch < num_epochs:
            model.train_mode()
            epoch += 1
            for x, y in data_loaders['train']:
                x = x.to(device).view(x.size(0), -1)
                y = y.to(device)
                iter_ += 1
                out = model.forward(x)
                loss = model.loss(out, y)
                loss.backward()
                _, predictions = out.max(dim=1)
                err_rate = 100.0 * (predictions != y).sum().item() / out.size(0)

                history['train_losses'].append(loss.item())
                history['train_errs'].append(err_rate)
                
                # disable gradient computations - we do not want torch to
                # backpropagate through the gradient application!
                #alpha = alpha_adjust(iter_, alpha)
                with torch.no_grad():
                    for (name, p), v in zip(model.parameters, velocities):
                        if name == 'W':  
                        #
                        # TODO: Implement weight decay addition to gradients
                        # p.grad += TODO
                          p.grad += regularisation * p
                        # 

                        #
                        # TODO: Update learning rate
                        # Hint: Use the iteration counter i
                        # alpha = TODO
                        #
                        if iter_ > 15000:
                            alpha = alpha0/ (1. + 1. * epoch )
                        #
                        # TODO: Set the momentum constant 
                        # epsilon = TODO
                        #
                        epsilon = 1e-8

                        #
                        # TODO: Implement velocity update in momentum
                        # lease make sure to modify the contents of v, not the v pointer!!!
                        # v[...] = TODO
                        #
                        v[...] = epsilon * v + p.grad * alpha

                        #
                        # TODO: Set a more sensible learning rule here,
                        #       using your learning rate schedule and momentum
                        # 
                        p -= alpha * v
                        # Zero gradients for the next iteration
                        p.grad.zero_()

                if iter_ % log_every == 0:
                    num_iter = iter_ - siter + 1
                    print "Minibatch {0: >6}  | loss {1: >5.2f} | err rate {2: >5.2f}%, steps/s {3: >5.2f}" \
                          .format(iter_, loss.item(), err_rate, num_iter / (time.time() - tstart))
                    tstart = time.time()
                           
            
            val_err_rate = compute_error_rate(model, data_loaders['valid'], device)
            history['val_errs'].append((iter_, val_err_rate))
            
            if val_err_rate < best_val_err:
                # Adjust num of epochs
                num_epochs = int(np.maximum(num_epochs, epoch * patience_expansion + 1))
                best_epoch = epoch
                best_val_err = val_err_rate
                best_params = [p.detach().cpu() for (_, p) in model.parameters]
            m = "After epoch {0: >2} | valid err rate: {1: >5.2f}% | doing {2: >3} epochs" \
                .format(epoch, val_err_rate, num_epochs)
            print '{0}\n{1}\n{0}'.format('-' * len(m), m)

    except KeyboardInterrupt:
        pass
    if best_params is not None:
        print "\nLoading best params on validation set (epoch %d)\n" %(best_epoch)
        model.parameters = best_params
    plot_history(history)

# %%
def plot_history(history):
    figsize(16, 4)
    subplot(1,2,1)
    train_loss = np.array(history['train_losses'])
    semilogy(np.arange(train_loss.shape[0]), train_loss, label='batch train loss')
    legend()
        
    subplot(1,2,2)
    train_errs = np.array(history['train_errs'])
    plot(np.arange(train_errs.shape[0]), train_errs, label='batch train error rate')
    val_errs = np.array(history['val_errs'])
    plot(val_errs[:,0], val_errs[:,1], label='validation error rate', color='r')
    ylim(0,20)
    legend()

# %% [markdown]
# # Problem 2: Tuning the Network for MNIST [4p]
#
# Tune the following network to reach **validation error rate below 1.9%**.
# This should result in a **test error rate below 2%**. To
# tune the network you will need to:
# 1. Choose the number of layers (more than 1, less than 5);
# 2. Choose the number of neurons in each layer (more than 100,
#     less than 5000);
# 3. Pick proper weight initialization;
# 4. Pick proper learning rate schedule (need to decay over time,
#     good range to check on MNIST is about 1e-2 ... 1e-1 at the beginning and
#     half of that after 10000 batches);
# 5. Pick a momentum constant (probably a constant one will be OK).

# %%
#
# TODO: Pick a network architecture here.
#       The one below is just softmax regression.
#

model = FeedforwardNet(
    [
     AffineLayer(784, 2000),
     TanhLayer(),
     AffineLayer(2000, 1000),
     ReLULayer(),      
     AffineLayer(1000, 10),
     SoftMaxLayer()
    ])


with torch.no_grad():
    # Initialize parameters
    for name, p in model.parameters:
        if name == 'W':
            p.normal_(0, 0.05)
            # p.data.uniform_(-0.1, 0.1)
        elif name == 'b':
            p.zero_()
        else:
            raise ValueError('Unknown parameter name "%s"' % p.name)

# On GPU enabled devices set device='cuda' else set device='cpu'
SGD(model, mnist_loaders, alpha=1e-1, device='cpu')

print "Test error rate: %.2f%%" % compute_error_rate(model, mnist_loaders['test'])
# Out:
# Training the model!
# Interrupt at any time to evaluate the best validation model so far.
# Minibatch    100  | loss  0.37 | err rate 10.94%, steps/s 10.19
# Minibatch    200  | loss  0.36 | err rate 10.16%, steps/s 21.21
# Minibatch    300  | loss  0.24 | err rate  7.03%, steps/s 32.00
# ----------------------------------------------------------
# After epoch  1 | valid err rate:  6.31% | doing   2 epochs
# ----------------------------------------------------------
# Minibatch    400  | loss  0.24 | err rate  8.59%, steps/s 31.42
# Minibatch    500  | loss  0.21 | err rate  5.47%, steps/s 53.24
# Minibatch    600  | loss  0.19 | err rate  4.69%, steps/s 63.92
# Minibatch    700  | loss  0.18 | err rate  7.03%, steps/s 75.00
# ----------------------------------------------------------
# After epoch  2 | valid err rate:  5.08% | doing   4 epochs
# ----------------------------------------------------------
# Minibatch    800  | loss  0.21 | err rate  7.03%, steps/s 62.56
# Minibatch    900  | loss  0.13 | err rate  3.91%, steps/s 96.54
# Minibatch   1000  | loss  0.10 | err rate  0.78%, steps/s 108.52
# Minibatch   1100  | loss  0.14 | err rate  3.91%, steps/s 119.55
# ----------------------------------------------------------
# After epoch  3 | valid err rate:  4.27% | doing   5 epochs
# ----------------------------------------------------------
# Minibatch   1200  | loss  0.19 | err rate  7.03%, steps/s 94.74
# Minibatch   1300  | loss  0.14 | err rate  3.12%, steps/s 139.84
# Minibatch   1400  | loss  0.13 | err rate  3.12%, steps/s 149.93
# Minibatch   1500  | loss  0.17 | err rate  4.69%, steps/s 160.99
# ----------------------------------------------------------
# After epoch  4 | valid err rate:  3.78% | doing   7 epochs
# ----------------------------------------------------------
# Minibatch   1600  | loss  0.09 | err rate  1.56%, steps/s 127.60
# Minibatch   1700  | loss  0.08 | err rate  2.34%, steps/s 183.77
# Minibatch   1800  | loss  0.12 | err rate  3.91%, steps/s 192.95
# Minibatch   1900  | loss  0.16 | err rate  3.12%, steps/s 206.63
# ----------------------------------------------------------
# After epoch  5 | valid err rate:  3.61% | doing   8 epochs
# ----------------------------------------------------------
# Minibatch   2000  | loss  0.10 | err rate  2.34%, steps/s 158.54
# Minibatch   2100  | loss  0.12 | err rate  5.47%, steps/s 226.95
# Minibatch   2200  | loss  0.15 | err rate  3.91%, steps/s 239.11
# Minibatch   2300  | loss  0.08 | err rate  2.34%, steps/s 249.29
# ----------------------------------------------------------
# After epoch  6 | valid err rate:  3.36% | doing  10 epochs
# ----------------------------------------------------------
# Minibatch   2400  | loss  0.08 | err rate  1.56%, steps/s 190.07
# Minibatch   2500  | loss  0.10 | err rate  1.56%, steps/s 266.23
# Minibatch   2600  | loss  0.08 | err rate  2.34%, steps/s 277.79
# Minibatch   2700  | loss  0.13 | err rate  3.12%, steps/s 291.23
# ----------------------------------------------------------
# After epoch  7 | valid err rate:  3.26% | doing  11 epochs
# ----------------------------------------------------------
# Minibatch   2800  | loss  0.06 | err rate  1.56%, steps/s 219.85
# Minibatch   2900  | loss  0.08 | err rate  1.56%, steps/s 311.53
# Minibatch   3000  | loss  0.11 | err rate  2.34%, steps/s 323.71
# Minibatch   3100  | loss  0.06 | err rate  0.78%, steps/s 335.97
# ----------------------------------------------------------
# After epoch  8 | valid err rate:  3.12% | doing  13 epochs
# ----------------------------------------------------------
# Minibatch   3200  | loss  0.07 | err rate  2.34%, steps/s 249.14
# Minibatch   3300  | loss  0.09 | err rate  2.34%, steps/s 351.34
# Minibatch   3400  | loss  0.07 | err rate  1.56%, steps/s 367.29
# Minibatch   3500  | loss  0.13 | err rate  3.91%, steps/s 375.37
# ----------------------------------------------------------
# After epoch  9 | valid err rate:  3.12% | doing  13 epochs
# ----------------------------------------------------------
# Minibatch   3600  | loss  0.07 | err rate  1.56%, steps/s 282.40
# Minibatch   3700  | loss  0.05 | err rate  0.78%, steps/s 394.69
# Minibatch   3800  | loss  0.05 | err rate  1.56%, steps/s 405.26
# Minibatch   3900  | loss  0.04 | err rate  0.78%, steps/s 425.73
# ----------------------------------------------------------
# After epoch 10 | valid err rate:  3.06% | doing  16 epochs
# ----------------------------------------------------------
# Minibatch   4000  | loss  0.05 | err rate  0.78%, steps/s 314.47
# Minibatch   4100  | loss  0.09 | err rate  1.56%, steps/s 443.90
# Minibatch   4200  | loss  0.08 | err rate  2.34%, steps/s 455.31
# Minibatch   4300  | loss  0.06 | err rate  1.56%, steps/s 475.39
# ----------------------------------------------------------
# After epoch 11 | valid err rate:  2.89% | doing  17 epochs
# ----------------------------------------------------------
# Minibatch   4400  | loss  0.09 | err rate  3.91%, steps/s 337.46
# Minibatch   4500  | loss  0.04 | err rate  1.56%, steps/s 484.47
# Minibatch   4600  | loss  0.05 | err rate  2.34%, steps/s 498.26
# ----------------------------------------------------------
# After epoch 12 | valid err rate:  2.82% | doing  19 epochs
# ----------------------------------------------------------
# Minibatch   4700  | loss  0.03 | err rate  0.00%, steps/s 371.38
# Minibatch   4800  | loss  0.05 | err rate  1.56%, steps/s 516.11
# Minibatch   4900  | loss  0.04 | err rate  0.00%, steps/s 524.14
# Minibatch   5000  | loss  0.05 | err rate  1.56%, steps/s 537.86
# ----------------------------------------------------------
# After epoch 13 | valid err rate:  2.75% | doing  20 epochs
# ----------------------------------------------------------
# Minibatch   5100  | loss  0.05 | err rate  1.56%, steps/s 404.70
# Minibatch   5200  | loss  0.03 | err rate  0.78%, steps/s 563.72
# Minibatch   5300  | loss  0.08 | err rate  2.34%, steps/s 566.90
# Minibatch   5400  | loss  0.07 | err rate  1.56%, steps/s 583.83
# ----------------------------------------------------------
# After epoch 14 | valid err rate:  2.77% | doing  20 epochs
# ----------------------------------------------------------
# Minibatch   5500  | loss  0.04 | err rate  1.56%, steps/s 430.55
# Minibatch   5600  | loss  0.07 | err rate  0.78%, steps/s 600.81
# Minibatch   5700  | loss  0.07 | err rate  1.56%, steps/s 610.12
# Minibatch   5800  | loss  0.02 | err rate  0.00%, steps/s 624.80
# ----------------------------------------------------------
# After epoch 15 | valid err rate:  2.66% | doing  23 epochs
# ----------------------------------------------------------
# Minibatch   5900  | loss  0.05 | err rate  0.00%, steps/s 460.07
# Minibatch   6000  | loss  0.03 | err rate  0.78%, steps/s 644.23
# Minibatch   6100  | loss  0.05 | err rate  0.78%, steps/s 656.28
# Minibatch   6200  | loss  0.02 | err rate  0.00%, steps/s 664.72
# ----------------------------------------------------------
# After epoch 16 | valid err rate:  2.69% | doing  23 epochs
# ----------------------------------------------------------
# Minibatch   6300  | loss  0.04 | err rate  0.78%, steps/s 490.59
# Minibatch   6400  | loss  0.05 | err rate  0.78%, steps/s 693.03
# Minibatch   6500  | loss  0.04 | err rate  0.78%, steps/s 699.08
# Minibatch   6600  | loss  0.02 | err rate  0.00%, steps/s 709.87
# ----------------------------------------------------------
# After epoch 17 | valid err rate:  2.63% | doing  26 epochs
# ----------------------------------------------------------
# Minibatch   6700  | loss  0.04 | err rate  0.00%, steps/s 526.03
# Minibatch   6800  | loss  0.08 | err rate  3.12%, steps/s 730.23
# Minibatch   6900  | loss  0.01 | err rate  0.00%, steps/s 750.14
# Minibatch   7000  | loss  0.05 | err rate  2.34%, steps/s 764.44
# ----------------------------------------------------------
# After epoch 18 | valid err rate:  2.56% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch   7100  | loss  0.03 | err rate  0.00%, steps/s 562.22
# Minibatch   7200  | loss  0.01 | err rate  0.00%, steps/s 773.95
# Minibatch   7300  | loss  0.05 | err rate  0.78%, steps/s 780.72
# Minibatch   7400  | loss  0.06 | err rate  1.56%, steps/s 791.76
# ----------------------------------------------------------
# After epoch 19 | valid err rate:  2.50% | doing  29 epochs
# ----------------------------------------------------------
# Minibatch   7500  | loss  0.04 | err rate  0.00%, steps/s 591.85
# Minibatch   7600  | loss  0.03 | err rate  0.00%, steps/s 824.31
# Minibatch   7700  | loss  0.05 | err rate  1.56%, steps/s 833.35
# Minibatch   7800  | loss  0.03 | err rate  0.00%, steps/s 839.40
# ----------------------------------------------------------
# After epoch 20 | valid err rate:  2.54% | doing  29 epochs
# ----------------------------------------------------------
# Minibatch   7900  | loss  0.03 | err rate  0.00%, steps/s 621.41
# Minibatch   8000  | loss  0.02 | err rate  0.00%, steps/s 865.25
# Minibatch   8100  | loss  0.06 | err rate  1.56%, steps/s 883.94
# Minibatch   8200  | loss  0.02 | err rate  0.00%, steps/s 896.52
# ----------------------------------------------------------
# After epoch 21 | valid err rate:  2.45% | doing  32 epochs
# ----------------------------------------------------------
# Minibatch   8300  | loss  0.06 | err rate  0.78%, steps/s 650.14
# Minibatch   8400  | loss  0.02 | err rate  0.78%, steps/s 902.29
# Minibatch   8500  | loss  0.03 | err rate  0.78%, steps/s 910.82
# Minibatch   8600  | loss  0.04 | err rate  0.00%, steps/s 953.64
# ----------------------------------------------------------
# After epoch 22 | valid err rate:  2.42% | doing  34 epochs
# ----------------------------------------------------------
# Minibatch   8700  | loss  0.04 | err rate  0.78%, steps/s 679.79
# Minibatch   8800  | loss  0.03 | err rate  0.00%, steps/s 949.74
# Minibatch   8900  | loss  0.03 | err rate  0.00%, steps/s 950.18
# ----------------------------------------------------------
# After epoch 23 | valid err rate:  2.37% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch   9000  | loss  0.03 | err rate  0.00%, steps/s 706.27
# Minibatch   9100  | loss  0.03 | err rate  0.00%, steps/s 971.34
# Minibatch   9200  | loss  0.03 | err rate  0.00%, steps/s 992.30
# Minibatch   9300  | loss  0.03 | err rate  0.78%, steps/s 1002.65
# ----------------------------------------------------------
# After epoch 24 | valid err rate:  2.38% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch   9400  | loss  0.07 | err rate  2.34%, steps/s 734.54
# Minibatch   9500  | loss  0.03 | err rate  0.78%, steps/s 1031.55
# Minibatch   9600  | loss  0.03 | err rate  0.00%, steps/s 1020.30
# Minibatch   9700  | loss  0.03 | err rate  0.00%, steps/s 1026.46
# ----------------------------------------------------------
# After epoch 25 | valid err rate:  2.39% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch   9800  | loss  0.01 | err rate  0.00%, steps/s 768.73
# Minibatch   9900  | loss  0.03 | err rate  0.78%, steps/s 1072.70
# Minibatch  10000  | loss  0.04 | err rate  0.78%, steps/s 1067.12
# Minibatch  10100  | loss  0.02 | err rate  0.00%, steps/s 1084.02
# ----------------------------------------------------------
# After epoch 26 | valid err rate:  2.38% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch  10200  | loss  0.02 | err rate  0.00%, steps/s 795.05
# Minibatch  10300  | loss  0.04 | err rate  0.00%, steps/s 1084.51
# Minibatch  10400  | loss  0.01 | err rate  0.00%, steps/s 1112.07
# Minibatch  10500  | loss  0.05 | err rate  1.56%, steps/s 1132.56
# ----------------------------------------------------------
# After epoch 27 | valid err rate:  2.37% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch  10600  | loss  0.04 | err rate  0.78%, steps/s 830.34
# Minibatch  10700  | loss  0.02 | err rate  0.00%, steps/s 1136.48
# Minibatch  10800  | loss  0.02 | err rate  0.00%, steps/s 1144.73
# Minibatch  10900  | loss  0.02 | err rate  0.00%, steps/s 1153.61
# ----------------------------------------------------------
# After epoch 28 | valid err rate:  2.32% | doing  43 epochs
# ----------------------------------------------------------
# Minibatch  11000  | loss  0.02 | err rate  0.00%, steps/s 861.87
# Minibatch  11100  | loss  0.02 | err rate  0.00%, steps/s 1194.58
# Minibatch  11200  | loss  0.02 | err rate  0.00%, steps/s 1198.31
# Minibatch  11300  | loss  0.02 | err rate  0.00%, steps/s 1212.80
# ----------------------------------------------------------
# After epoch 29 | valid err rate:  2.38% | doing  43 epochs
# ----------------------------------------------------------
# Minibatch  11400  | loss  0.03 | err rate  0.00%, steps/s 885.33
# Minibatch  11500  | loss  0.01 | err rate  0.00%, steps/s 1224.93
# Minibatch  11600  | loss  0.05 | err rate  0.78%, steps/s 1244.57
# Minibatch  11700  | loss  0.02 | err rate  0.00%, steps/s 1255.37
# ----------------------------------------------------------
# After epoch 30 | valid err rate:  2.35% | doing  43 epochs
# ----------------------------------------------------------
# Minibatch  11800  | loss  0.02 | err rate  0.78%, steps/s 918.14
# Minibatch  11900  | loss  0.02 | err rate  0.00%, steps/s 1277.26
# Minibatch  12000  | loss  0.02 | err rate  0.00%, steps/s 1279.44
# Minibatch  12100  | loss  0.03 | err rate  1.56%, steps/s 1304.84
# ----------------------------------------------------------
# After epoch 31 | valid err rate:  2.37% | doing  43 epochs
# ----------------------------------------------------------
# Minibatch  12200  | loss  0.03 | err rate  0.78%, steps/s 966.15
# Minibatch  12300  | loss  0.01 | err rate  0.00%, steps/s 1330.95
# Minibatch  12400  | loss  0.05 | err rate  1.56%, steps/s 1309.23
# Minibatch  12500  | loss  0.02 | err rate  0.78%, steps/s 1357.27
# ----------------------------------------------------------
# After epoch 32 | valid err rate:  2.31% | doing  49 epochs
# ----------------------------------------------------------
# Minibatch  12600  | loss  0.02 | err rate  0.00%, steps/s 976.80
# Minibatch  12700  | loss  0.02 | err rate  0.00%, steps/s 1367.11
# Minibatch  12800  | loss  0.03 | err rate  0.78%, steps/s 1394.72
# Minibatch  12900  | loss  0.04 | err rate  0.78%, steps/s 1461.50
# ----------------------------------------------------------
# After epoch 33 | valid err rate:  2.26% | doing  50 epochs
# ----------------------------------------------------------
# Minibatch  13000  | loss  0.02 | err rate  0.78%, steps/s 1013.84
# Minibatch  13100  | loss  0.03 | err rate  0.00%, steps/s 1419.84
# Minibatch  13200  | loss  0.02 | err rate  0.00%, steps/s 1416.25
# ----------------------------------------------------------
# After epoch 34 | valid err rate:  2.34% | doing  50 epochs
# ----------------------------------------------------------
# Minibatch  13300  | loss  0.04 | err rate  0.78%, steps/s 1048.22
# Minibatch  13400  | loss  0.03 | err rate  0.00%, steps/s 1457.89
# Minibatch  13500  | loss  0.02 | err rate  0.00%, steps/s 1468.07
# Minibatch  13600  | loss  0.02 | err rate  0.00%, steps/s 1473.19
# ----------------------------------------------------------
# After epoch 35 | valid err rate:  2.29% | doing  50 epochs
# ----------------------------------------------------------
# Minibatch  13700  | loss  0.02 | err rate  0.00%, steps/s 1078.40
# Minibatch  13800  | loss  0.02 | err rate  0.00%, steps/s 1468.11
# Minibatch  13900  | loss  0.01 | err rate  0.00%, steps/s 1493.86
# Minibatch  14000  | loss  0.02 | err rate  0.00%, steps/s 1510.68
# ----------------------------------------------------------
# After epoch 36 | valid err rate:  2.28% | doing  50 epochs
# ----------------------------------------------------------
# Minibatch  14100  | loss  0.01 | err rate  0.00%, steps/s 1119.04
# Minibatch  14200  | loss  0.02 | err rate  0.00%, steps/s 1533.93
# Minibatch  14300  | loss  0.02 | err rate  0.00%, steps/s 1548.76
# Minibatch  14400  | loss  0.01 | err rate  0.00%, steps/s 1548.92
# ----------------------------------------------------------
# After epoch 37 | valid err rate:  2.29% | doing  50 epochs
# ----------------------------------------------------------
# Minibatch  14500  | loss  0.02 | err rate  0.00%, steps/s 1150.34
# Minibatch  14600  | loss  0.01 | err rate  0.00%, steps/s 1596.50
# Minibatch  14700  | loss  0.01 | err rate  0.00%, steps/s 1613.54
# Minibatch  14800  | loss  0.02 | err rate  0.00%, steps/s 1609.09
# ----------------------------------------------------------
# After epoch 38 | valid err rate:  2.28% | doing  50 epochs
# ----------------------------------------------------------
# Minibatch  14900  | loss  0.03 | err rate  0.00%, steps/s 1162.35
# Minibatch  15000  | loss  0.03 | err rate  0.00%, steps/s 1612.54
# Minibatch  15100  | loss  0.02 | err rate  0.00%, steps/s 1637.79
# Minibatch  15200  | loss  0.02 | err rate  0.00%, steps/s 1668.65
# ----------------------------------------------------------
# After epoch 39 | valid err rate:  2.28% | doing  50 epochs
# ----------------------------------------------------------
# Minibatch  15300  | loss  0.01 | err rate  0.00%, steps/s 1225.45
# Minibatch  15400  | loss  0.02 | err rate  0.00%, steps/s 1642.13
# Minibatch  15500  | loss  0.01 | err rate  0.00%, steps/s 1657.79
# Minibatch  15600  | loss  0.01 | err rate  0.00%, steps/s 1680.80
# ----------------------------------------------------------
# After epoch 40 | valid err rate:  2.29% | doing  50 epochs
# ----------------------------------------------------------
# Minibatch  15700  | loss  0.02 | err rate  0.00%, steps/s 1246.90
# Minibatch  15800  | loss  0.02 | err rate  0.00%, steps/s 1743.28
# Minibatch  15900  | loss  0.01 | err rate  0.00%, steps/s 1738.01
# Minibatch  16000  | loss  0.02 | err rate  0.00%, steps/s 1740.47
# ----------------------------------------------------------
# After epoch 41 | valid err rate:  2.29% | doing  50 epochs
# ----------------------------------------------------------
# Minibatch  16100  | loss  0.02 | err rate  0.00%, steps/s 1273.30
# Minibatch  16200  | loss  0.01 | err rate  0.00%, steps/s 1744.06
# Minibatch  16300  | loss  0.03 | err rate  0.78%, steps/s 1772.20
# Minibatch  16400  | loss  0.03 | err rate  0.00%, steps/s 1788.54
# ----------------------------------------------------------
# After epoch 42 | valid err rate:  2.29% | doing  50 epochs
# ----------------------------------------------------------
# Minibatch  16500  | loss  0.02 | err rate  0.78%, steps/s 1314.85
# Minibatch  16600  | loss  0.01 | err rate  0.00%, steps/s 1803.10
# Minibatch  16700  | loss  0.01 | err rate  0.00%, steps/s 1797.02
# Minibatch  16800  | loss  0.02 | err rate  0.00%, steps/s 1832.77
# ----------------------------------------------------------
# After epoch 43 | valid err rate:  2.28% | doing  50 epochs
# ----------------------------------------------------------
# Minibatch  16900  | loss  0.01 | err rate  0.00%, steps/s 1325.54
# Minibatch  17000  | loss  0.02 | err rate  0.00%, steps/s 1859.51
# Minibatch  17100  | loss  0.01 | err rate  0.00%, steps/s 1862.08
# Minibatch  17200  | loss  0.03 | err rate  0.78%, steps/s 1910.86
# ----------------------------------------------------------
# After epoch 44 | valid err rate:  2.28% | doing  50 epochs
# ----------------------------------------------------------
# Minibatch  17300  | loss  0.03 | err rate  0.00%, steps/s 1344.17
# Minibatch  17400  | loss  0.01 | err rate  0.00%, steps/s 1860.70
# Minibatch  17500  | loss  0.02 | err rate  0.00%, steps/s 1899.11
# ----------------------------------------------------------
# After epoch 45 | valid err rate:  2.28% | doing  50 epochs
# ----------------------------------------------------------
# Minibatch  17600  | loss  0.02 | err rate  0.00%, steps/s 1411.84
# Minibatch  17700  | loss  0.02 | err rate  0.00%, steps/s 1919.88
# Minibatch  17800  | loss  0.01 | err rate  0.00%, steps/s 1922.28
# Minibatch  17900  | loss  0.02 | err rate  0.00%, steps/s 1895.98
# ----------------------------------------------------------
# After epoch 46 | valid err rate:  2.28% | doing  50 epochs
# ----------------------------------------------------------
# Minibatch  18000  | loss  0.02 | err rate  0.00%, steps/s 1413.16
# Minibatch  18100  | loss  0.03 | err rate  0.00%, steps/s 1968.08
# Minibatch  18200  | loss  0.01 | err rate  0.00%, steps/s 1978.65
# Minibatch  18300  | loss  0.02 | err rate  0.00%, steps/s 2001.68
# ----------------------------------------------------------
# After epoch 47 | valid err rate:  2.28% | doing  50 epochs
# ----------------------------------------------------------
# Minibatch  18400  | loss  0.02 | err rate  0.78%, steps/s 1459.43
# Minibatch  18500  | loss  0.02 | err rate  0.00%, steps/s 1961.40
# Minibatch  18600  | loss  0.02 | err rate  0.00%, steps/s 1978.28
# Minibatch  18700  | loss  0.01 | err rate  0.00%, steps/s 2020.75
# ----------------------------------------------------------
# After epoch 48 | valid err rate:  2.29% | doing  50 epochs
# ----------------------------------------------------------
# Minibatch  18800  | loss  0.02 | err rate  0.00%, steps/s 1506.52
# Minibatch  18900  | loss  0.01 | err rate  0.00%, steps/s 2045.68
# Minibatch  19000  | loss  0.03 | err rate  1.56%, steps/s 2056.95
# Minibatch  19100  | loss  0.03 | err rate  0.78%, steps/s 2051.03
# ----------------------------------------------------------
# After epoch 49 | valid err rate:  2.29% | doing  50 epochs
# ----------------------------------------------------------
# Minibatch  19200  | loss  0.01 | err rate  0.00%, steps/s 1489.61
# Minibatch  19300  | loss  0.03 | err rate  0.78%, steps/s 2086.75
# Minibatch  19400  | loss  0.02 | err rate  0.00%, steps/s 2113.60
# Minibatch  19500  | loss  0.01 | err rate  0.00%, steps/s 2096.07
# ----------------------------------------------------------
# After epoch 50 | valid err rate:  2.29% | doing  50 epochs
# ----------------------------------------------------------
#
# Loading best params on validation set (epoch 33)
#
# Test error rate: 2.31%

# %% [markdown]
# # Problem 3: Dropout [2p]
#
# Implement a **dropout** layer and try to train a
# network getting below 1.5% test error rates with dropout. The best
# results with dropout are below 1%!
#
# Remember to turn off dropout during testing, using `model.train_mode()` and `model.eval_mode()`!
#
# Hint: Use [torch.nn.functional.dropout](http://pytorch.org/docs/master/nn.html#torch.nn.functional.dropout).
#
# Details: http://arxiv.org/pdf/1207.0580.pdf.

# %%
class DropOutLayer(Layer):
    def forward(self, x):
        return F.alpha_dropout(x, p= 0.25,  training=self.training_mode)

# %%
dropout_model = FeedforwardNet(
    [
     # DropoutLayer(0.2),
     AffineLayer(784, 400),
     ReLULayer(),
     DropOutLayer(),
     AffineLayer(400, 400),
     TanhLayer(),
     DropOutLayer(),
     AffineLayer(400, 10),
     SoftMaxLayer()
    ])

# Initialize parameters
with torch.no_grad():
    for p in dropout_model.parameters:
        if p.name == 'W':
             p.data.normal_(0, 0.05)
        # p.data.uniform_(-0.1, 0.1)
        elif p.name == 'b':
             p.data.zero_()
        else:
            raise ValueError('Unknown parameter name "%s"' % p.name)

# On lab computers you can set cuda=True !
SGD(dropout_model, mnist_loaders, alpha=1e-1, epsilon=0.5, beta = 1e-3, c = 0.99993, cuda=True)

print "Test error rate: %.2f%%" % compute_error_rate(dropout_model, mnist_loaders['test'])
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-14-96d41c695ab1> in <module>()
#      15 with torch.no_grad():
#      16     for p in dropout_model.parameters:
# ---> 17         if p.name == 'W':
#      18              p.data.normal_(0, 0.05)
#      19         # p.data.uniform_(-0.1, 0.1)
#
# AttributeError: 'tuple' object has no attribute 'name'

# %% [markdown]
# # Problem 4: Data Augmentation [1p]
#
# Apply data augmentation methods (e.g. rotations, noise, crops) when training networks on MNIST, to significantly reduce test error rate for your network. You can use functions from the [torchvision.transforms](http://pytorch.org/docs/master/torchvision/transforms.html) module.

# %% [markdown]
# # Problem 5: Batch Normalization [1p]
#
# *Covariate shift* is a phenomenon associated with training deep models. Simply put, weight changes in early layers cause major changes in distribution of inputs to later layers, making it difficult to train later layers.
#
# [Batch Normalization](https://arxiv.org/abs/1502.03167) addresses this problem by normalizing distributions of inputs to layers within mini-batches. It typically allows to train networks faster and/or with higher learning rates, lessens the importance
# of initialization and might eliminate the need for Dropout.
#
# Implement Batch Normalization and compare with regular training of MNIST models.
#
# Remember to use the batch statistics during model training and to use an average of training batch statistics during model evaluation. For details please consult the paper.

# %% [markdown]
# # Problem 6: Norm Constraints [1p bonus]
#
# Implement norm constraints, i.e. instead of weight decay, that tries to set
# all weights to small values, apply a limit on the total
# norm of connections incoming to a neuron. In our case, this
# corresponds to clipping the norm of *rows* of weight
# matrices. An easy way of implementing it is to make a gradient
# step, then look at the norm of rows and scale down those that are
# over the threshold (this technique is called "projected gradient descent").
#
# Please consult the Dropout paper (http://arxiv.org/pdf/1207.0580.pdf) for details.

# %% [markdown]
# # Problem 6: Polyak Averaging [1p bonus]
#
# Implement Polyak averaging. For each parameter $\theta$
# keep a separate, exponentially decayed average of the past values
# $$
# \bar{\theta}_n = \alpha_p\bar{\theta}_{n-1} + (1-\alpha_p)\theta_n.
# $$
# Use that average when evaluating the model on the test set.
# Validate the approach by training a model on the MNIST dataset.

# %% [markdown]
# # Problem 7: Convolutional Network [2p bonus]
#
# Use convolutional and max-pooling layers (`torch.nn.functional.conv2d`, `torch.nn.functional.max_pool2d`) and (without dropout) get a test error rate below 1.5%.

# %% [markdown]
# # Problem 8: Hyperparameter tuner [1p bonus]
#
# Implement a hyper-parameter tuner able to optimize the learing rate schedule, number of neurons and similar hyperparameters. For start, use random search (please see http://jmlr.csail.mit.edu/papers/volume13/bergstra12a/bergstra12a.pdf and especially Fig 1. for intuitions on why random search is better than grid search). It may be a good idea to use a fixed maximum number of epochs (or training time) for each optimization trial to prevent selecting hyperparameters that yield slowly converging solutions. A good result will be a set of hyperparameters that reach on MNIST solutions with test errors less than $1.3\%$ in no more than 50 epochs.
